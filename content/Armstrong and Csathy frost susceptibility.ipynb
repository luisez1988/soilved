# %%
import pandas as pd
import matplotlib.pyplot as plt
import Soilved as slv

# %%
upper=pd.read_csv("./data/upper.csv")
upper['PP1']=upper['PP']
upper['PP2']=upper['PP']
upper['PP3']=upper['PP']
slv.GetSoilFrostLimits(upper)
plt.savefig('frost_limits.svg')
